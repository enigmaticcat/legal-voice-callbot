# %% [markdown]
# # Nutrition CallBot — Embedding + Qdrant Ingest
#
# Pipeline:
# 1. Chạy Qdrant 1.12.0 local trên Colab (binary, không cần Docker)
# 2. Upload `corpus_final.jsonl` lên `/content/`
# 3. Embed bằng `AITeamVN/Vietnamese_Embedding` (1024-dim)
# 4. Upsert vào Qdrant local
# 5. Tạo snapshot → save lên Google Drive
#
# **Yêu cầu trước khi chạy:**
# - Runtime: GPU T4 (Runtime → Change runtime type → T4 GPU)
# - Upload `corpus_final.jsonl` lên `/content/` (Files panel bên trái hoặc drag-drop)

# %%
# Cell 1: Tải và chạy Qdrant 1.12.0 binary
# !wget -q https://github.com/qdrant/qdrant/releases/download/v1.12.0/qdrant-x86_64-unknown-linux-musl.tar.gz
# !tar -xzf qdrant-x86_64-unknown-linux-musl.tar.gz
# !chmod +x qdrant

import subprocess, time, urllib.request

proc = subprocess.Popen(
    ['./qdrant'],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.DEVNULL,
)

# Chờ Qdrant ready
for i in range(30):
    time.sleep(1)
    try:
        resp = urllib.request.urlopen('http://localhost:6333/')
        print('Qdrant ready:', resp.read().decode())
        break
    except:
        print(f'  Waiting... ({i+1}s)')
else:
    print('ERROR: Qdrant failed to start')

# %%
# Cell 2: Cài dependencies
# !pip install -q sentence-transformers qdrant-client

# %%
# Cell 3: CONFIG
QDRANT_URL       = "http://localhost:6333"
COLLECTION       = "nutrition_articles"
DATA_PATH        = "/content/corpus_final.jsonl"
MODEL_NAME       = "AITeamVN/Vietnamese_Embedding"
EMBED_BATCH_SIZE = 64    # giảm xuống 32 nếu OOM
MAX_CHUNKS       = None  # None = toàn bộ; đặt 200 để test nhanh trước

# %%
# Cell 4: Load chunks
import json

print(f"Loading {DATA_PATH}...")
chunks = []
bad_lines = 0
with open(DATA_PATH, "r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        line = line.strip()
        if not line:
            continue
        try:
            chunks.append(json.loads(line))
        except json.JSONDecodeError as e:
            bad_lines += 1
            if bad_lines <= 3:
                print(f"  [WARN] Line {i+1} loi JSON: {e} | preview: {line[:80]}")

total = len(chunks)
if bad_lines:
    print(f"\n[WARN] {bad_lines} lines bi loi va da bo qua")

if MAX_CHUNKS:
    chunks = chunks[:MAX_CHUNKS]
    print(f"Loaded {total:,} chunks -> gioi han test: {len(chunks):,}")
else:
    print(f"Loaded {total:,} chunks")

sources = {}
for c in chunks:
    sources[c["source"]] = sources.get(c["source"], 0) + 1
print("\nPhan bo:")
for src, cnt in sorted(sources.items()):
    print(f"  {src}: {cnt:,} chunks")

c0 = chunks[0]
print(f"\nVi du chunk dau tien:")
print(f"  chunk_id : {c0['chunk_id']}")
print(f"  title    : {c0['title'][:80]}")
print(f"  text     : {c0['text'][:150]}...")

# %%
# Cell 5: Load embedding model
from sentence_transformers import SentenceTransformer
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")

print(f"\nLoading {MODEL_NAME}... (lan dau ~3 phut)")
model = SentenceTransformer(MODEL_NAME, device=device)

DIM = model.get_sentence_embedding_dimension()
print(f"Model loaded! Dim: {DIM}")

test = model.encode(["passage: Dinh duong la gi?"], normalize_embeddings=True)
print(f"Test vector shape: {test.shape}")

# %%
# Cell 6: Ket noi Qdrant + tao collection
from qdrant_client import QdrantClient
from qdrant_client.http import models
import hashlib, uuid

qdrant = QdrantClient(url=QDRANT_URL, timeout=60)
info = qdrant.get_collections()
print(f"Ket noi OK! Collections: {[c.name for c in info.collections]}")

if qdrant.collection_exists(COLLECTION):
    print(f"Xoa collection cu: {COLLECTION}")
    qdrant.delete_collection(COLLECTION)

qdrant.create_collection(
    collection_name=COLLECTION,
    vectors_config=models.VectorParams(size=DIM, distance=models.Distance.COSINE),
)

for field in ["source", "category", "doc_id"]:
    qdrant.create_payload_index(COLLECTION, field, field_schema="keyword")

print(f"Tao collection '{COLLECTION}' (dim={DIM}) thanh cong")

# %%
# Cell 7: Embed + Upload
import time

def make_uuid(chunk_id: str) -> str:
    h = hashlib.md5(chunk_id.encode()).hexdigest()
    return str(uuid.UUID(h))


def embed_and_upload(chunks_list, batch_size=EMBED_BATCH_SIZE):
    total = len(chunks_list)
    uploaded = 0
    t_start = time.time()

    for batch_start in range(0, total, batch_size):
        batch = chunks_list[batch_start : batch_start + batch_size]
        texts = [f"passage: {c['embed_text']}" for c in batch]
        vecs = model.encode(texts, normalize_embeddings=True, show_progress_bar=False)

        points = [
            models.PointStruct(
                id=make_uuid(c["chunk_id"]),
                vector=vecs[i].tolist(),
                payload={
                    "chunk_id"   : c["chunk_id"],
                    "doc_id"     : c["doc_id"],
                    "source"     : c["source"],
                    "url"        : c["url"],
                    "title"      : c["title"],
                    "category"   : c["category"],
                    "chunk_index": c["chunk_index"],
                    "text"       : c["text"],
                },
            )
            for i, c in enumerate(batch)
        ]

        qdrant.upsert(collection_name=COLLECTION, points=points)
        uploaded += len(batch)

        elapsed = time.time() - t_start
        speed = uploaded / elapsed
        eta = (total - uploaded) / speed if speed > 0 else 0
        if uploaded % (batch_size * 20) == 0 or uploaded == total:
            print(
                f"  {uploaded:,}/{total:,} ({uploaded/total*100:.1f}%) | "
                f"{speed:.0f} chunks/s | ETA: {eta/60:.1f} min"
            )

    print(f"\nHoan tat! {uploaded:,} vectors | {(time.time()-t_start)/60:.1f} phut")


print(f"Bat dau embedding + upload {len(chunks):,} chunks...")
embed_and_upload(chunks)

col_info = qdrant.get_collection(COLLECTION)
print(f"\nQdrant '{COLLECTION}': {col_info.points_count:,} vectors da luu")

# %%
# Cell 8: Tao snapshot + save len Google Drive
import requests, shutil, os
from google.colab import drive

drive.mount('/content/drive')

print("Tao snapshot...")
resp = requests.post(f"{QDRANT_URL}/collections/{COLLECTION}/snapshots")
snap_name = resp.json()["result"]["name"]
print(f"Snapshot: {snap_name}")

snap_url = f"{QDRANT_URL}/collections/{COLLECTION}/snapshots/{snap_name}"
drive_path = f"/content/drive/MyDrive/{snap_name}"

print(f"Saving -> {drive_path}")
with requests.get(snap_url, stream=True) as r:
    r.raise_for_status()
    with open(drive_path, "wb") as f:
        shutil.copyfileobj(r.raw, f)

size_mb = os.path.getsize(drive_path) / (1024*1024)
print(f"Done! {drive_path} ({size_mb:.0f} MB)")
